# %%
from utils.wind_analysis import wind_analysis_polar
from utils.consts import benin_file_path, togo_file_path, sierraleone_file_path

# %%
print("Wind Analysis for benin")
wind_analysis_polar(benin_file_path)
# Out:
# Wind Analysis for benin

# %%
print("Wind Analysis for togo")
wind_analysis_polar(togo_file_path)
# Out:
# Wind Analysis for togo

# %%
print("Wind Analysis for sierraleon")
wind_analysis_polar(sierraleone_file_path)
# Out:
# Wind Analysis for sierraleon
