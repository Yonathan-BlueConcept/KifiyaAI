# %%
from utils.visualize_correlations import visualize_correlations
from utils.consts import sierraleone_file_path, benin_file_path, togo_file_path

# %%
print("Correlation For Benin")
visualize_correlations(benin_file_path)
# Out:
# Time Series For Benin

# %%
print("Correlation For Togo")
visualize_correlations(togo_file_path)
# Out:
# Time Series For Togo

# %%
print("Correlation For Sieralleon")
visualize_correlations(sierraleone_file_path)
# Out:
# Time Series For Sieralleon
